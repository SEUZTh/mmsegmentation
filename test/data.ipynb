# %%
# 读取这个图片/Users/zth/Downloads/CHASEDB1/Image_08R_2ndHO.png
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/media/zth/T7/毕业设计/数据集/ttpla-DatasetNinja/chasedb1_format/annotations/training/4_00363_mask.png')
plt.imshow(img)
plt.show()

# %%
# 看看前景和背景的像素值分别是多少？
import numpy as np
print(np.unique(img))
print(img.shape)
# Out:
# [  0 255]
# (2160, 3840, 3)
